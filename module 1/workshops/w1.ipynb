# %%
import numpy as np

# %% [markdown]
# Point 1

# %%
u = np.array( [ 2, 7, 1 ] )
v = np.array( [ -3, 0, 4 ] )
w = np.array( [ 0, 5, -8 ] )

# %%
u + v + v
# Out:
# array([-4,  7,  9])

# %%
u + 3 * v - 5 * w
# Out:
# array([ -7, -18,  53])

# %% [markdown]
# Point 2

# %%
u = np.array( [ 3, -2, 1, 4 ] )
v = np.array( [ 7, 1, -3, 6 ] )

# %%
u + v
# Out:
# array([10, -1, -2, 10])

# %%
u - v
# Out:
# array([-4, -3,  4, -2])

# %%
u + 3 * v
# Out:
# array([24,  1, -8, 22])

# %%
np.dot( u, v )
# Out:
# 40

# %%
np.linalg.norm( u )
# Out:
# 5.477225575051661

# %%
np.sqrt( 30 )
# Out:
# 5.477225575051661

# %%
np.linalg.norm( u - v )
# Out:
# 6.708203932499369

# %%
np.sqrt( 45 )
# Out:
# 6.708203932499369

# %% [markdown]
# Point 3

# %% [markdown]
# Point 4

# %% [markdown]
# Point 5

# %% [markdown]
# Point 6

# %% [markdown]
# Point 7

# %%
np.linalg.norm( np.array( [ 2, 2 ] ) )
# Out:
# 2.8284271247461903

# %%
2 * np.sqrt( 2 )
# Out:
# 2.8284271247461903

# %%
np.linalg.norm( np.array( [ 2, 2 * np.sqrt( 3 ) ] ) )
# Out:
# 3.9999999999999996

# %%
np.linalg.norm( np.array( [ -2 * np.sqrt( 3 ), 2 ] ) )
# Out:
# 3.9999999999999996

# %%
np.linalg.norm( np.array( [ -3, -3 ] ) )
# Out:
# 4.242640687119285

# %%
3 * np.sqrt( 2 )
# Out:
# 4.242640687119286

# %%
np.linalg.norm( np.array( [ 6, -6 ] ) )
# Out:
# 8.48528137423857

# %%
3 * np.sqrt( 8 )
# Out:
# 8.485281374238571

# %%
np.linalg.norm( np.array( [ 0, 3 ] ) )
# Out:
# 3.0

# %% [markdown]
# Point 8

# %%
z = 2 + 3j
w = 5 - 2j

# %%
z + w
# Out:
# (7+1j)

# %%
np.dot( z, w )
# Out:
# (16+11j)

# %%
z - 2 * w
# Out:
# (-8+7j)

# %%
np.linalg.norm( z )
# Out:
# 3.605551275463989

# %%
np.sqrt( 13 )
# Out:
# 3.605551275463989

# %% [markdown]
# Point 9

# %%
z = 2 + 3j
w = 12 -5j

# %%
np.linalg.norm( z )
# Out:
# 3.605551275463989

# %%
np.sqrt( 13 )
# Out:
# 3.605551275463989

# %%
np.linalg.norm( w )
# Out:
# 13.0

# %%
np.sqrt( 169 )
# Out:
# 13.0

# %%
z + w
# Out:
# (14-2j)

# %%
np.dot( z, w )
# Out:
# (39+26j)

# %% [markdown]
# Point 10

# %%
np.array( [ 3, -4, 5 ] ) + np.array( [ 1, 1, -2 ] )
# Out:
# array([ 4, -3,  3])

# %%
-3 * np.array( [ 4, -5, -6 ] )
# Out:
# array([-12,  15,  18])

# %%
-1 * np.array( [ -6, 7, -8 ] )
# Out:
# array([ 6, -7,  8])

# %% [markdown]
# Point 11

# %%
np.dot( np.array( [ 2, 3, -6 ] ), np.array( [ 8, 2, -3 ] ) )
# Out:
# 40

# %%
np.dot( np.array( [ 3, -5, 2, 1 ] ), np.array( [ 4, 1, -2, 5 ] ) )
# Out:
# 8

# %% [markdown]
# Point 12

# %% [markdown]
# Point 13

# %%
np.linalg.norm( np.array( [ 1, 7 ] ) - np.array( [ 6, -5 ] ) )
# Out:
# 13.0

# %%
np.linalg.norm( np.array( [ 3, -5, 4 ] ) - np.array( [ 6, 2, -1 ] ) )
# Out:
# 9.1104335791443

# %%
np.sqrt( 83 )
# Out:
# 9.1104335791443

# %%
np.linalg.norm( np.array( [ 5, 3, -2, -4, -1 ] ) - np.array( [ 2, -1, 0, -7, 2 ] ) )
# Out:
# 6.855654600401044

# %%
np.sqrt( 47 )
# Out:
# 6.855654600401044

# %% [markdown]
# Point 14

# %%
np.linalg.norm( np.array( [ 2, -7 ] ) )
# Out:
# 7.280109889280518

# %%
np.sqrt( 53 )
# Out:
# 7.280109889280518

# %%
np.linalg.norm( np.array( [ 3, -12, -4 ] ) )
# Out:
# 13.0

# %% [markdown]
# Point 15

# %%
np.linalg.norm( np.array( [ -4, 5 ] ) )
# Out:
# 6.4031242374328485

# %%
np.sqrt( 41 )
# Out:
# 6.4031242374328485

# %%
np.linalg.norm( np.array( [ 4, 3 * np.sqrt( 7 ) ] ) )
# Out:
# 8.888194417315589

# %%
np.sqrt( 79 )
# Out:
# 8.888194417315589

# %%
np.linalg.norm( np.array( [ -7 * np.sqrt( 7 ), -2 ] ) )
# Out:
# 18.62793601019716

# %%
np.sqrt( 347 )
# Out:
# 18.627936010197157

# %%
np.linalg.norm( np.array( [ -4, -7 ] ) )
# Out:
# 8.06225774829855

# %%
np.sqrt( 65 )
# Out:
# 8.06225774829855

# %%
np.linalg.norm( np.array( [ 6, -4 ] ) )
# Out:
# 7.211102550927978

# %%
np.sqrt( 52 )
# Out:
# 7.211102550927978

# %%
np.linalg.norm( np.array( [ 10, 7 ] ) )
# Out:
# 12.206555615733702

# %%
np.sqrt( 149 )
# Out:
# 12.206555615733702

# %% [markdown]
# Point 16

# %%
z = 2 - 3j
w = 4 + 5j

# %%
z + w
# Out:
# (6+2j)

# %%
np.dot( z, w )
# Out:
# (23-2j)

# %%
np.linalg.norm( z )
# Out:
# 3.605551275463989

# %%
np.sqrt( 13 )
# Out:
# 3.605551275463989

# %%
np.linalg.norm( w )
# Out:
# 6.4031242374328485

# %%
np.sqrt( 41 )
# Out:
# 6.4031242374328485

# %% [markdown]
# Point 17

# %%
np.dot( np.array( [ 2, 0, -3 ] ), np.array( [ 4, 0, 2 ] ) )
# Out:
# 2

# %%
np.dot( np.array( [ 4, 1, 5 ] ), np.array( [ 7, 2, -3 ] ) )
# Out:
# 15

# %%
np.dot( np.array( [ 2, 0, 3 ] ), np.array( [ 7, 2, -3 ] ) )
# Out:
# 5
